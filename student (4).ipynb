# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name: Josiah Okumu,Victor Mawira, Mary Wairimu,Lavender Echessa
# * Student pace:  full time
# * Scheduled project review date/time: 21/4/2023
# * Instructor name: William Okomba
# * Blog post URL:https://github.com/Victormawira/Group-3.2-Phase-2-project.git

# %% [markdown]
# # INTRODUCTION
#
# The King County House Sales dataset is a valuable resource for understanding the dynamics of the real estate market in King County. This dataset contains detailed information on house sale prices including a wide range of features such as the number of bedrooms, bathrooms, square footage, location, and more.This dataset allows for in-depth analysis and modeling to understand the factors that influence housing prices in the region, and serves as a valuable resource for developing and testing predictive models for accurate price predictions.
#
# Housing has been the long-term focus of urban development and social and economic policies, not only to the medium level economies but also to the high economies.House Price prediction are very stressful work as we have to consider different things while buying a house like the structure and the rooms kitchen parking space ,the period/time of purchase/ sale of the houses,the bedroom number,the house grade,the year it was built and the floors.
# It can further be argued that the subject of ‘affordability’ of housing has become unclear because it addresses numerous issues as already explained on the above factors that come to play when determining the prices of houses in various parts of the globe.
# To establish how diffrent factors affect housing prices The use of multiple linear regression modelling can easily help identify the house which is to be perfect for the customers and helps to predict the price accurately.It will also enable the house owners while making decisions on which houses to sell and the rate they earn after  the renovations . The renovations done to some houses and others left out will help determine if they do raise the values of the houses or not thus giving quality advice to the home owners.

# %% [markdown]
# ## CHALLENGES
#
# >Home renovation is the remodeling of a home with the aim of improving the design through making additions and repairs. Some home owners may conduct these processes with the aim of improving the monetary value especially at the onset of selling the property. However, not all renovations yield to larger profits as most of them are time consuming which could lead to loss of potential customers especially in high-demand zones.Also, in some instances structural defects might be encountered during the renovation process which will lead to additional cost to repair reducing the profit margin as the renovation cost will increase.Over-renovating: Over-renovating can be a common mistake when renovating a property for resale, diffrent customers have different preferences.Legal restrictions: There may be legal restrictions on what you can and cannot do when renovating a property. For example, there may be zoning restrictions, building codes, or historic preservation laws that limit what you can do. Quality of work: The quality of workmanship is essential when renovating a home. If the work is poor or the materials used are of low quality,it will lead to loss.Selling in a competitive market: selling in a competitive market can be challenging

# %% [markdown]
# ### PROPOSED SOLUTIONS

# %% [markdown]
#  To help the real estate agency provide advice to homeowners about home renovations, we can analyze the King County House Sales dataset using regression analysis. We can build a predictive model that estimates the increase in home value for different types of renovations, taking into account the cost of the renovation, the location of the home, and other relevant factors. We can then use this model to recommend specific renovations to homeowners based on their budget, location, and other preferences.

# %% [markdown]
# ## PROBLEM STATEMENT
#
# The Northwestern County housing situation is one that is worth investigating as housing pricing within region is something that cannot be ignored since it affects the majority. the industry is also one that is operating in a very competitive market, just like in other parts of the globe.
# The real estate agency within the county have contacted a group of data scientists to help inform the homeowners when to buy/or and sell homes. The specific issue in this case will be to help homeowners make appropriate decision, on whether renovation affects the property values, hence pricing or whether other factors like bedroom and areas of both house and compounds can as well influence the pricing.
# The specific issues to be established in this case is the factors that affects the pricing of houses and homes in the Northwestern county.

# %% [markdown]
# ### Objectives

# %% [markdown]
# 1. To identify the factors that affects the prices of homes in Northwestern county
#
# 2. To create a model that can hellp to predict the price of a house in Northwestern county

# %% [markdown]
# #### LOADING THE DATA

# %%
# Your code here - remember to use markdown cells for comments as well!
#imports and loading in data
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
import warnings
warnings.filterwarnings("ignore")
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

df = pd.read_csv('data/kc_house_data.csv')
df
# Out:
#                id        date     price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  10/13/2014  221900.0         3       1.00         1180
# 1      6414100192   12/9/2014  538000.0         3       2.25         2570
# 2      5631500400   2/25/2015  180000.0         2       1.00          770
# 3      2487200875   12/9/2014  604000.0         4       3.00         1960
# 4      1954400510   2/18/2015  510000.0         3       2.00         1680
# ...           ...         ...       ...       ...        ...          ...
# 21592   263000018   5/21/2014  360000.0         3       2.50         1530
# 21593  6600060120   2/23/2015  400000.0         4       2.50         2310
# 21594  1523300141   6/23/2014  402101.0         2       0.75         1020
# 21595   291310100   1/16/2015  400000.0         3       2.50         1600
# 21596  1523300157  10/15/2014  325000.0         2       0.75         1020
#
#        sqft_lot  floors waterfront  view  ...          grade sqft_above  \
# ...

# %%
#finding data head
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors waterfront  view  ...          grade sqft_above  \
# 0      5650     1.0        NaN  NONE  ...      7 Average       1180
# 1      7242     2.0         NO  NONE  ...      7 Average       2170
# 2     10000     1.0         NO  NONE  ...  6 Low Average        770
# 3      5000     1.0         NO  NONE  ...      7 Average       1050
# 4      8080     1.0         NO  NONE  ...         8 Good       1680
#
#    sqft_basement yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
#finding data tail
df.tail()
# Out:
#                id        date     price  bedrooms  bathrooms  sqft_living  \
# 21592   263000018   5/21/2014  360000.0         3       2.50         1530
# 21593  6600060120   2/23/2015  400000.0         4       2.50         2310
# 21594  1523300141   6/23/2014  402101.0         2       0.75         1020
# 21595   291310100   1/16/2015  400000.0         3       2.50         1600
# 21596  1523300157  10/15/2014  325000.0         2       0.75         1020
#
#        sqft_lot  floors waterfront  view  ...      grade sqft_above  \
# 21592      1131     3.0         NO  NONE  ...     8 Good       1530
# 21593      5813     2.0         NO  NONE  ...     8 Good       2310
# 21594      1350     2.0         NO  NONE  ...  7 Average       1020
# 21595      2388     2.0        NaN  NONE  ...     8 Good       1600
# 21596      1076     2.0         NO  NONE  ...  7 Average       1020
#
#        sqft_basement yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %% [markdown]
# ## BASIC DATA UNDERSTANDING

# %%
#shape of the data
df.shape
# Out:
# (21597, 21)

# %%
len(df)
# Out:
# 21597

# %%
# info for overview of the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21597 non-null  int64
#  1   date           21597 non-null  object
#  2   price          21597 non-null  float64
#  3   bedrooms       21597 non-null  int64
#  4   bathrooms      21597 non-null  float64
#  5   sqft_living    21597 non-null  int64
#  6   sqft_lot       21597 non-null  int64
#  7   floors         21597 non-null  float64
#  8   waterfront     19221 non-null  object
#  9   view           21534 non-null  object
#  10  condition      21597 non-null  object
#  11  grade          21597 non-null  object
#  12  sqft_above     21597 non-null  int64
#  13  sqft_basement  21597 non-null  object
#  14  yr_built       21597 non-null  int64
#  15  yr_renovated   17755 non-null  float64
#  16  zipcode        21597 non-null  int64
# ...

# %% [markdown]
# > Based on the above the data has 21597 rows and 21 columns.The data types is either numerical or categorical; six floats, nine integers and six objects columns.

# %% [markdown]
# ### Converting column data types
#
# When looking at the data we can see there are some problems with the datatypes you would expect from certain variables. Problems that we found were:
# 1.  Sqft_basement, view and yr_renovated,yr_built should be ints.

# %%
df = df.loc[df['yr_renovated']!= '?']#removes any rows where 'yr_built' is missing or invalid.
df.yr_renovated = df.yr_renovated.astype('object')# converts the 'yr_renovated' column to object

# %%
df = df.loc[df['sqft_basement']!= '?']#removes any rows where 'yr_built' is missing or invalid.
df.sqft_basement = df.sqft_basement.astype('float64').astype('int64')# converts the 'sqft_basement' column to float64 to int64 data type

# %%
df.yr_built = df.yr_built.astype('object')# converts the 'yr_built' column to object

# %% [markdown]
# #### Ensuring Correct Data Types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21143 entries, 0 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21143 non-null  int64
#  1   date           21143 non-null  object
#  2   price          21143 non-null  float64
#  3   bedrooms       21143 non-null  int64
#  4   bathrooms      21143 non-null  float64
#  5   sqft_living    21143 non-null  int64
#  6   sqft_lot       21143 non-null  int64
#  7   floors         21143 non-null  float64
#  8   waterfront     18804 non-null  object
#  9   view           21082 non-null  object
#  10  condition      21143 non-null  object
#  11  grade          21143 non-null  object
#  12  sqft_above     21143 non-null  int64
#  13  sqft_basement  21143 non-null  int64
#  14  yr_built       21143 non-null  object
#  15  yr_renovated   17389 non-null  object
#  16  zipcode        21143 non-null  int64
# ...

# %% [markdown]
# ### Revised data types

# %%
df.select_dtypes(include='object').head()
# Out:
#          date waterfront  view  condition          grade yr_built yr_renovated
# 0  10/13/2014        NaN  NONE    Average      7 Average     1955            0
# 1   12/9/2014         NO  NONE    Average      7 Average     1951         1991
# 2   2/25/2015         NO  NONE    Average  6 Low Average     1933          NaN
# 3   12/9/2014         NO  NONE  Very Good      7 Average     1965            0
# 4   2/18/2015         NO  NONE    Average         8 Good     1987            0

# %%
df.select_dtypes(include=['int64','float64']).head()
# Out:
#            id     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  7129300520  221900.0         3       1.00         1180      5650     1.0
# 1  6414100192  538000.0         3       2.25         2570      7242     2.0
# 2  5631500400  180000.0         2       1.00          770     10000     1.0
# 3  2487200875  604000.0         4       3.00         1960      5000     1.0
# 4  1954400510  510000.0         3       2.00         1680      8080     1.0
#
#    sqft_above  sqft_basement  zipcode      lat     long  sqft_living15  \
# 0        1180              0    98178  47.5112 -122.257           1340
# 1        2170            400    98125  47.7210 -122.319           1690
# 2         770              0    98028  47.7379 -122.233           2720
# 3        1050            910    98136  47.5208 -122.393           1360
# 4        1680              0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# ...

# %%
# describe for descriptive statistics
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.114300e+04  2.114300e+04  21143.000000  21143.000000  21143.000000
# mean   4.581004e+09  5.405107e+05      3.372558      2.116079   2080.920730
# std    2.876328e+09  3.680751e+05      0.924917      0.768531    918.547562
# min    1.000102e+06  7.800000e+04      1.000000      0.500000    370.000000
# 25%    2.123049e+09  3.220000e+05      3.000000      1.750000   1430.000000
# 50%    3.904940e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.309100e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    sqft_above  sqft_basement       zipcode  \
# count  2.114300e+04  21143.000000  21143.000000   21143.000000  21143.000000
# mean   1.508714e+04      1.493591   1789.069006     291.851724  98077.868893
# ...

# %%
#column check
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %% [markdown]
# > The columns with mising values are; waterfront 2376, veiw 63, yr_renovated 3842. There are no duplicates. The coulumns have no inconsistencies in the naming.

# %% [markdown]
# #### Showing categorical data features

# %%
df.select_dtypes(include="object").head()
# Out:
#          date waterfront  view  condition          grade yr_built yr_renovated
# 0  10/13/2014        NaN  NONE    Average      7 Average     1955            0
# 1   12/9/2014         NO  NONE    Average      7 Average     1951         1991
# 2   2/25/2015         NO  NONE    Average  6 Low Average     1933          NaN
# 3   12/9/2014         NO  NONE  Very Good      7 Average     1965            0
# 4   2/18/2015         NO  NONE    Average         8 Good     1987            0

# %% [markdown]
# #### Showing numerical data features

# %%
df.select_dtypes(include=["int64","float64"]).head()
# Out:
#            id     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  7129300520  221900.0         3       1.00         1180      5650     1.0
# 1  6414100192  538000.0         3       2.25         2570      7242     2.0
# 2  5631500400  180000.0         2       1.00          770     10000     1.0
# 3  2487200875  604000.0         4       3.00         1960      5000     1.0
# 4  1954400510  510000.0         3       2.00         1680      8080     1.0
#
#    sqft_above  sqft_basement  zipcode      lat     long  sqft_living15  \
# 0        1180              0    98178  47.5112 -122.257           1340
# 1        2170            400    98125  47.7210 -122.319           1690
# 2         770              0    98028  47.7379 -122.233           2720
# 3        1050            910    98136  47.5208 -122.393           1360
# 4        1680              0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# ...

# %% [markdown]
# > There are 7 columns in categorical data and 14 columns in numerical data.

# %% [markdown]
# ## DATA CLEANING
# In this step, the following will be achieved:
#
# 1. Ensuring columns are the right data types
# 2. Identifying and dealing with null values
# 3. identifying outliers and removing them

# %% [markdown]
# #### Checking for duplicates

# %%
#finding total number of duplicates
# Duplicated entries
def identify_duplicates(df):
    """Simple function to identify any duplicates"""
    # identify the duplicates (dataframename.duplicated() , can add .sum() to get total count)
    # empty list to store Bool results from duplicated
    duplicates = []
    for i in df.duplicated():
        duplicates.append(i)
    # identify if there is any duplicates. (If there is any we expect a True value in the list duplicates)
    duplicates_set = set(duplicates) 
    if (len(duplicates_set) == 1):
        print("The Data has no duplicates")
    else:
        no_true = 0
        for val in duplicates:
            if (val == True):
                no_true += 1
        # percentage of the data represented by duplicates 
        duplicates_percentage = np.round(((no_true / len(df)) * 100), 3)
        print(f"The Data has {no_true} duplicated rows.\nThis constitutes {duplicates_percentage}% of the data set.") 



identify_duplicates(df)
# Out:
# The Data has no duplicates

# %% [markdown]
# #### Checking for missing values

# %%
#checking for missing values in df
def identify_missing_values(df):
    """Identify is the data has missing values"""
    # identify if df has missing values(df.isnull().any())
    # empty dict to store missing values
    missing = []
    for i in df.isnull().any():
        # add the bool values to empty list 
        missing.append(i)
    # covert list to set (if data has missing value, the list should have true and false)
    missing_set = set(missing)
    if (len(missing_set) == 1):
        out = print("The Data has no missing values")
    else:
        out = print("The Data has missing values.")

    return out


identify_missing_values(df)
# Out:
# The Data has missing values.

# %%
df.isna().sum()
# Out:
# id                  0
# date                0
# price               0
# bedrooms            0
# bathrooms           0
# sqft_living         0
# sqft_lot            0
# floors              0
# waterfront       2339
# view               61
# condition           0
# grade               0
# sqft_above          0
# sqft_basement       0
# yr_built            0
# yr_renovated     3754
# zipcode             0
# lat                 0
# long                0
# sqft_living15       0
# sqft_lot15          0
# dtype: int64

# %%
def missing_values(df):
    """A simple function to identify df has missing values"""
    # identify the total missing values per column
    # sort in order 
    miss = df.isnull().sum().sort_values(ascending = False)

    # calculate percentage of the missing values
    percentage_miss = (df.isnull().sum() / len(df)).sort_values(ascending = False)

    # store in a dataframe 
    missing = pd.DataFrame({"Missing Values": miss, "Percentage(%)": percentage_miss})

    # remove values that are missing 
    missing.drop(missing[missing["Percentage(%)"] == 0].index, inplace = True)

    return missing


missing_data = missing_values(df)
missing_data
# Out:
#               Missing Values  Percentage(%)
# yr_renovated            3754       0.177553
# waterfront              2339       0.110628
# view                      61       0.002885

# %%
def graph_missing(data):
    """Graphically represent the missing values"""
    fig, axes = plt.subplots(figsize = (10, 8))
    # plot a bargraph
    sns.barplot(x = data.index , y = data["Missing Values"])
    # labeling the axes 
    plt.xlabel("Columns", fontdict={"color": "black", "size": 15})
    # rotating our xticks 
    plt.xticks(rotation = '60')
    # labeling the y axis 
    plt.ylabel("Missing Values", fontdict={"color": "black", "size": 15})
    # title 
    plt.title("Missing Values per Column", fontsize = 18)
    # display
    plt.show()

    # save the plot 
    fig.savefig("missing.png")


graph_missing(missing_data)

# %% [markdown]
# Observation
#
# Year_renovated had the highest missing value followed by waterfront and then view.

# %%
df['view'].value_counts()
# Out:
# NONE         19018
# AVERAGE        930
# GOOD           496
# FAIR           327
# EXCELLENT      311
# Name: view, dtype: int64

# %%
df1 = df.fillna(method='bfill')
df1
# Out:
#                id        date     price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  10/13/2014  221900.0         3       1.00         1180
# 1      6414100192   12/9/2014  538000.0         3       2.25         2570
# 2      5631500400   2/25/2015  180000.0         2       1.00          770
# 3      2487200875   12/9/2014  604000.0         4       3.00         1960
# 4      1954400510   2/18/2015  510000.0         3       2.00         1680
# ...           ...         ...       ...       ...        ...          ...
# 21592   263000018   5/21/2014  360000.0         3       2.50         1530
# 21593  6600060120   2/23/2015  400000.0         4       2.50         2310
# 21594  1523300141   6/23/2014  402101.0         2       0.75         1020
# 21595   291310100   1/16/2015  400000.0         3       2.50         1600
# 21596  1523300157  10/15/2014  325000.0         2       0.75         1020
#
#        sqft_lot  floors waterfront  view  ...          grade sqft_above  \
# ...

# %%
df1.isna().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %% [markdown]
# > We decided to backfill because we had no categorical columns

# %% [markdown]
# ### consistent row naming

# %%
df1 = df1.rename(index={
    0: 'Row_1',
    1: 'Row_2',
    2: 'Row_3',
    3: 'Row_4',
    4: 'Row_5,'
   
})

#the updated dataframe
df1.head()
# Out:
#                 id        date     price  bedrooms  bathrooms  sqft_living  \
# Row_1   7129300520  10/13/2014  221900.0         3       1.00         1180
# Row_2   6414100192   12/9/2014  538000.0         3       2.25         2570
# Row_3   5631500400   2/25/2015  180000.0         2       1.00          770
# Row_4   2487200875   12/9/2014  604000.0         4       3.00         1960
# Row_5,  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#         sqft_lot  floors waterfront  view  ...          grade sqft_above  \
# Row_1       5650     1.0         NO  NONE  ...      7 Average       1180
# Row_2       7242     2.0         NO  NONE  ...      7 Average       2170
# Row_3      10000     1.0         NO  NONE  ...  6 Low Average        770
# Row_4       5000     1.0         NO  NONE  ...      7 Average       1050
# Row_5,      8080     1.0         NO  NONE  ...         8 Good       1680
#
#         sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %% [markdown]
# We have used rename() method is used to rename the rows in the dataframe using a dictionary that maps the old row numbers to the new row names. The updated dataframe displays the first 5 rows.

# %% [markdown]
# ### Checking for Outliers
#
# >We can use a box plot to identify outliers in datasets

# %%
numerical_cols=['bedrooms','bathrooms','sqft_living','sqft_lot']
for col in numerical_cols:
    sns.boxplot(x=df1[col])
    plt.show()

# %% [markdown]
# We have used quantile() method is used to calculate the lower and upper bounds for each column, which are defined as the 5th and 95th percentiles, respectively.The df1 is filtered to exclude any rows that fall outside those bounds using boolean indexing.

# %%
df1['bedrooms'].value_counts()
# Out:
# 3     9639
# 4     6740
# 2     2691
# 5     1560
# 6      262
# 1      191
# 7       36
# 8       13
# 9        6
# 10       3
# 11       1
# 33       1
# Name: bedrooms, dtype: int64

# %%
df1[df1['bedrooms'] == 33]
df.loc[15856, 'bedrooms'] = 3

# %%
df2=df.loc[15856, 'bedrooms'] = 3
df2
# Out:
# 3

# %%
df1.iloc[15518:15521, :]
# Out:
#                id       date     price  bedrooms  bathrooms  sqft_living  \
# 15856  2402100895  6/25/2014  640000.0        33       1.75         1620
# 15857  3750604417  5/26/2014  172500.0         3       1.00         1140
# 15858  9547202890  1/20/2015  596000.0         2       1.00         1040
#
#        sqft_lot  floors waterfront  view  ...      grade sqft_above  \
# 15856      6000     1.0         NO  NONE  ...  7 Average       1040
# 15857      8800     1.0         NO  NONE  ...  7 Average       1140
# 15858      4880     1.0         NO  NONE  ...  7 Average       1040
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 15856            580      1947           0.0    98103  47.6878 -122.331
# 15857              0      1972        1975.0    98001  47.2629 -122.275
# 15858              0      1910        1975.0    98115  47.6809 -122.311
#
#        sqft_living15  sqft_lot15
# 15856           1330        4700
# 15857           1270       13560
# ...

# %%
df1['bathrooms']=df1["bathrooms"].round().astype(int)
df1["bathrooms"].value_counts()
df1
# Out:
#                 id        date     price  bedrooms  bathrooms  sqft_living  \
# Row_1   7129300520  10/13/2014  221900.0         3          1         1180
# Row_2   6414100192   12/9/2014  538000.0         3          2         2570
# Row_3   5631500400   2/25/2015  180000.0         2          1          770
# Row_4   2487200875   12/9/2014  604000.0         4          3         1960
# Row_5,  1954400510   2/18/2015  510000.0         3          2         1680
# ...            ...         ...       ...       ...        ...          ...
# 21592    263000018   5/21/2014  360000.0         3          2         1530
# 21593   6600060120   2/23/2015  400000.0         4          2         2310
# 21594   1523300141   6/23/2014  402101.0         2          1         1020
# 21595    291310100   1/16/2015  400000.0         3          2         1600
# 21596   1523300157  10/15/2014  325000.0         2          1         1020
#
# ...

# %%
df1['bathrooms'] =  df1['bathrooms'].round().astype(int)
df1['bathrooms'].value_counts()
# Out:
# 2    13568
# 1     3837
# 3     2470
# 4     1181
# 5       55
# 6       23
# 8        4
# 0        3
# 7        2
# Name: bathrooms, dtype: int64

# %% [markdown]
# We have used round() method is used to round off the values in the bathrooms column to whole numbers and the astype() method is used to convert the column to integer data type.The updated dataframe is printed to the console using the head() method to display the first 5 rows

# %%
df1['floors'] =  df1['floors'].round().astype(int)
df1['floors'].value_counts()
# Out:
# 1    10456
# 2    10087
# 3      593
# 4        7
# Name: floors, dtype: int64

# %%
num_cols=['bedrooms','bathrooms','sqft_living','sqft_lot']
for col in num_cols:
    sns.boxplot(x=df1[col])
    plt.show()

# %% [markdown]
# After eliminating a typing error the boxplots shows the outcome of the different column values.

# %% [markdown]
# ## EXPLORATORY DATA ANALYSIS

# %% [markdown]
# #### Numerical Data Distribution

# %%
fig = plt.figure(figsize=(28,160))
num_vars = df1.select_dtypes(['int64', 'float64']).columns.tolist()
num_vars.remove('id')
for index, col in enumerate(num_vars):
    plt.subplot(26,2,index+1)
    sns.histplot(x=col, data=df1)
    plt.ylabel('COUNT', size = 25)
    plt.xlabel(col, fontsize = 25)
    plt.xticks(size = 20, rotation = 45 )
    plt.yticks(size = 20)
fig.tight_layout(pad=1.0)

# %% [markdown]
# #### Observations
#
# The distribution of 'Price' is skew to the left. For the linear model like linear regression, this may have a negative effect on the predictions.Therefore, logarithm may be used to transform the target variable so that it follow a normal distribution as you can see in the chart below. Below are the distribution of 'Price' before and after it is applied logarithm.

# %%
fig = plt.figure(figsize=(20,5))
sns.histplot(x='price', data=df, bins=300, kde=True)
# Out:
# <AxesSubplot:xlabel='price', ylabel='Count'>

# %% [markdown]
# The price distribution is skewed to the right, meaning that most of the prices are below the mean.

# %% [markdown]
# #### Normalized numerical distributions

# %%
tran_y = df1.price.apply(np.log)
# tran_y.hist(bins=200)
fig = plt.figure(figsize=(20,5))
sns.histplot(data=tran_y, bins=300, kde=True)
# Out:
# <AxesSubplot:xlabel='price', ylabel='Count'>

# %% [markdown]
# #### Observation
# The  Price is normal after logarithm transformation as above

# %% [markdown]
# #### Normalized data

# %%
df1_cont = df.iloc[:,0:10]
df1_cont.hist(figsize=(12,12))
# Out:
# array([[<AxesSubplot:title={'center':'id'}>,
#         <AxesSubplot:title={'center':'price'}>,
#         <AxesSubplot:title={'center':'bedrooms'}>],
#        [<AxesSubplot:title={'center':'bathrooms'}>,
#         <AxesSubplot:title={'center':'sqft_living'}>,
#         <AxesSubplot:title={'center':'sqft_lot'}>],
#        [<AxesSubplot:title={'center':'floors'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %% [markdown]
# We get to see the distribution of diffrent features against their count upon normalization

# %% [markdown]
# ### Categorical Data Distiribution

# %%
fig = plt.figure(figsize=(26,160))
cat_vars = df.select_dtypes(['object']).columns.tolist()
for index, col in enumerate(cat_vars):
    plt.subplot(25,2,index+1)
    sns.countplot(x=col, data=df)
    plt.ylabel('COUNT', size = 25)
    plt.xlabel(col, fontsize = 25)
    plt.xticks(size = 20, rotation = 45)
    plt.yticks(size = 20)
fig.tight_layout(pad=1.0)

# %% [markdown]
# Categorical features in the data are visualized as above.

# %% [markdown]
# ### Data Correlation

# %%
# Get not null train categorical features
categorical_features = df1.select_dtypes('object').columns.tolist()
na_series = df1[categorical_features].isnull().sum() > 0
categorical_missing_features = na_series[na_series == True].index.tolist()
used_cate_features = list(set(categorical_features).difference(
    set(categorical_missing_features)))
# Get not null train numerical features
num_features = df1.select_dtypes(
    ['int64', 'float64']).columns.tolist()
na_series = df1[num_features].isnull().sum() > 0
num_missing_features = na_series[na_series == True].index.tolist()
used_num_features = list(
    set(num_features).difference(set(num_missing_features)))
used_features = used_cate_features + used_num_features
sns.set(rc = {'figure.figsize':(15, 10)})
axis_corr = sns.heatmap(
    df1[used_num_features].corr(),
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(50, 500, n=500),
    square=True
)
plt.show()

# %% [markdown]
# Variable features are correlated based on the magnitude shown on heatmap.

# %% [markdown]
# #### Scatter relationship

# %%
num_df = df1.select_dtypes(exclude=['object'])
num_features = list(num_df.columns)
num_features.remove('price')
fig = plt.figure(figsize=(30, 180))
for i, feature in enumerate(num_features):
    plt.subplot(20, 2,i+1)
    sns.scatterplot(data=num_df, x=feature, y='price')
    plt.ylabel('price', size=15)
    plt.yticks(size=15)
    plt.xlabel(feature, size=20)
    plt.xticks(size=15)

# %% [markdown]
# Observations
#
# All features above have relationship with price of the house and so we will use them in forming the models.

# %%
num_df = df1.select_dtypes(exclude=['object'])
num_df = num_df.drop(labels=['id'], axis=1)
num_features = list(num_df.columns)
fig = plt.figure(figsize=(30, 180))
for i, feature in enumerate(num_features):
    plt.subplot(20, 2, i+1)
    sns.boxplot(data=num_df, x=feature)
    plt.ylabel('price', size=15)
    plt.yticks(size=15)
    plt.xlabel(feature, size=20)
    plt.xticks(size=15)

# %% [markdown]
# Observations
#
# The boxplot shows distibution of variables which will help us to determine the variables for consideration.

# %% [markdown]
# # MODELLING

# %% [markdown]
# ### Simple linear Regression

# %%
df1.corr()
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.015796  0.002487  -0.004967    -0.011721 -0.132268
# price         -0.015796  1.000000  0.309204   0.519032     0.702328  0.087937
# bedrooms       0.002487  0.309204  1.000000   0.487532     0.577998  0.032262
# bathrooms     -0.004967  0.519032  0.487532   1.000000     0.701847  0.090399
# sqft_living   -0.011721  0.702328  0.577998   0.701847     1.000000  0.172941
# sqft_lot      -0.132268  0.087937  0.032262   0.090399     0.172941  1.000000
# floors         0.017651  0.244631  0.180767   0.328811     0.322818 -0.003717
# sqft_above    -0.010567  0.605143  0.479210   0.600056     0.876678  0.183461
# sqft_basement -0.004548  0.325008  0.302683   0.333533     0.434576  0.015533
# yr_built       0.022218  0.054459  0.157017   0.379223     0.319461  0.052768
# yr_renovated  -0.013111  0.108645  0.017922   0.057016     0.045376  0.002592
# ...

# %%
df1.drop('id', axis = 1, inplace = True)
df1
# Out:
#               date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# Row_1   10/13/2014  221900.0         3          1         1180      5650
# Row_2    12/9/2014  538000.0         3          2         2570      7242
# Row_3    2/25/2015  180000.0         2          1          770     10000
# Row_4    12/9/2014  604000.0         4          3         1960      5000
# Row_5,   2/18/2015  510000.0         3          2         1680      8080
# ...            ...       ...       ...        ...          ...       ...
# 21592    5/21/2014  360000.0         3          2         1530      1131
# 21593    2/23/2015  400000.0         4          2         2310      5813
# 21594    6/23/2014  402101.0         2          1         1020      1350
# 21595    1/16/2015  400000.0         3          2         1600      2388
# 21596   10/15/2014  325000.0         2          1         1020      1076
#
#         floors waterfront  view  condition          grade  sqft_above  \
# ...

# %%
df1.drop('zipcode', axis = 1, inplace = True)
df1
# Out:
#               date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# Row_1   10/13/2014  221900.0         3          1         1180      5650
# Row_2    12/9/2014  538000.0         3          2         2570      7242
# Row_3    2/25/2015  180000.0         2          1          770     10000
# Row_4    12/9/2014  604000.0         4          3         1960      5000
# Row_5,   2/18/2015  510000.0         3          2         1680      8080
# ...            ...       ...       ...        ...          ...       ...
# 21592    5/21/2014  360000.0         3          2         1530      1131
# 21593    2/23/2015  400000.0         4          2         2310      5813
# 21594    6/23/2014  402101.0         2          1         1020      1350
# 21595    1/16/2015  400000.0         3          2         1600      2388
# 21596   10/15/2014  325000.0         2          1         1020      1076
#
#         floors waterfront  view  condition          grade  sqft_above  \
# ...

# %% [markdown]
# #### Multicollinearity testing

# %%
sns.set(style = 'white')

corr = df1.corr()

mask = np.zeros_like(corr, dtype = np.bool)
mask[np.triu_indices_from(mask)] = True

f, ax = plt.subplots(figsize= (12,12))

cmap = sns.diverging_palette(220, 10, as_cmap=True)

sns.heatmap(corr, mask = mask, cmap = cmap, vmax = .75, center = 0, square = True, linewidth = .5, cbar_kws = {'shrink':.5})
# Out:
# <AxesSubplot:>

# %% [markdown]
# observation
#
# The features shown above are not highly correlated to each other but shows high correlation to the price.

# %%
abs(df1.corr()) > .75
# Out:
#                price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# price           True     False      False        False     False   False
# bedrooms       False      True      False        False     False   False
# bathrooms      False     False       True        False     False   False
# sqft_living    False     False      False         True     False   False
# sqft_lot       False     False      False        False      True   False
# floors         False     False      False        False     False    True
# sqft_above     False     False      False         True     False   False
# sqft_basement  False     False      False        False     False   False
# yr_built       False     False      False        False     False   False
# yr_renovated   False     False      False        False     False   False
# lat            False     False      False        False     False   False
# long           False     False      False        False     False   False
# ...

# %% [markdown]
# The heatmap suggests that both the sqft of the living room and the sqft of the basement may cause collinearity. Further inspection with an absolute correlation value of .75 suggest that sqft living room is highly correlated with the bathrooms & sqft above.

# %%
#Declaring variables for simple linear regression
X=df1["sqft_living"]
y=df1["price"]
baseline_model=sm.OLS(endog=y, exog=sm.add_constant(X)).fit()
baseline_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.493
# Model:                            OLS   Adj. R-squared:                  0.493
# Method:                 Least Squares   F-statistic:                 2.058e+04
# Date:                Thu, 20 Apr 2023   Prob (F-statistic):               0.00
# Time:                        20:11:04   Log-Likelihood:            -2.9378e+05
# No. Observations:               21143   AIC:                         5.876e+05
# Df Residuals:                   21141   BIC:                         5.876e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const       -4.513e+04   4462.443    -10.113      0.000   -5.39e+04   -3.64e+04
# ...

# %% [markdown]
# $y$ = 281.43$x$ - 4.513e+04
#
# 1. p.value=0.00 at $\alpha$= 0.05
#
# 2. The model is statistically significant overall, with an F-statistic p-value well below 0.05
#
# 3. The model coefficients (const and sqft_living) are both statistically significant, with t-statistic p-values well below 0.05
#
# 4. For each increase of sqft living 1, we see price increases by 281.43
# 5. Our model explains 49.3% of the variance of price.

# %% [markdown]
# R squared is 49.3%, indicating that only 49.3% of the variance in price  is explained by our model.
# Therefore we evaluate this by computation of RMSE.

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2, random_state=0)

# %%
# Define X_train and y_train. As single feature need to reshape X_train into column vector
X_train = np.array(df1['sqft_living']).reshape(-1,1)
y_train = df1['price']

# %%
# Define X_train and y_train. As single feature need to reshape X_train into column vector
X_train = np.array(df1['sqft_living']).reshape(-1,1)
y_train = df1['price']

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr
# Out:
# LinearRegression()

# %%
# Evaluate using rmse
from sklearn.model_selection import cross_val_score

scores = cross_val_score(
            lr, 
            X_train,
            y_train,
            cv=10,
            scoring="neg_mean_squared_error"
)

rmse_scores = np.sqrt(-scores)
display(rmse_scores)
display(rmse_scores.mean())
display(rmse_scores.std())
# Out:
# array([273924.28244927, 280882.6263449 , 246097.51636916, 277434.57388233,
#        253489.46010677, 249475.25471393, 248167.02081801, 260237.38977758,
#        262317.27724487, 266876.79320491])
# 261890.21949117206
# 11989.066047787603

# %% [markdown]
# The RMSE is the mean error in $ ie.on aaverage the actual price will be USD 261890 more or less than predicted price. This is not a bad value for the one feature that we used. T he standard deviation of around USD 11980 is also decent,meaning that our model does not appear to be over fitting

# %%
# Create visualisation of simple linear regression
# Create a Linear Regression model
lr = LinearRegression()

# Fit the model with training data
lr.fit(X_train, y_train)

# Get predictions
y_pred = lr.predict(X_train)

# Plot data points
plt.scatter(x = X_train[:2000], y = y_train[:2000], alpha = 0.2, label = 'Data Points')

# Plot regression line
plt.plot(X_train, y_pred, color = 'red', label = 'Regression Line')

plt.legend()
plt.title('Simple linear regression using sqft_living feature')
plt.xlabel('Living area (sqft)')
plt.ylabel('Price (USD)')
plt.show()

# %% [markdown]
# We see that for smaller living areas our model looks decent but as the sqft_living value increases our model's performance declines, signifiying that sqft_living is not a good enough predictor for larger houses.
#
# We will want to keep track of our models so let us build a table which will have the name of the model and key metrics.

# %%
# Define table as a dataframe with specific columns. Each column's values will be a list that we will add to.
evaluationtable = pd.DataFrame({'baseline_model': [], 'Description':[], ' Num Features' : [], 'R-squared':[],
                                'Adj R-squared':[], 'RMSE': [],'RMSE sd':[]})

# Add data for simple linear regression
evaluationtable.loc[0] = ['Simple Linear Regression', 'Sqft_living',baseline_model.df_model, round(baseline_model.rsquared,3)
                          ,round(baseline_model.rsquared_adj,3), int(rmse_scores.mean()), int(rmse_scores.std()) ]

# View our evaluation table
evaluationtable
# Out:
#              baseline_model  Description   Num Features  R-squared  \
# 0  Simple Linear Regression  Sqft_living            1.0      0.493
#
#    Adj R-squared      RMSE  RMSE sd
# 0          0.493  261890.0  11989.0

# %% [markdown]
# ### Multilinear  Regression

# %% [markdown]
# Our objective was to determine how factors pricing.

# %%
# creating dummies usng the sklearn model and the label encoder to eliminate the object type data;
from sklearn.preprocessing import LabelEncoder
# Create a LabelEncoder object
le = LabelEncoder()
# Apply the LabelEncoder to each object type column in the dataframe, loping through the data since there are many columns which are object type;
for col in df1.columns:
    if df1[col].dtype == 'object':
        df1[col] = le.fit_transform(df1[col])
# Print the updated dataframe with numerical data
df1
# Out:
#         date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# Row_1     30  221900.0         3          1         1180      5650       1
# Row_2    114  538000.0         3          2         2570      7242       2
# Row_3    132  180000.0         2          1          770     10000       1
# Row_4    114  604000.0         4          3         1960      5000       1
# Row_5,   124  510000.0         3          2         1680      8080       1
# ...      ...       ...       ...        ...          ...       ...     ...
# 21592    223  360000.0         3          2         1530      1131       3
# 21593    130  400000.0         4          2         2310      5813       2
# 21594    265  402101.0         2          1         1020      1350       2
# 21595      5  400000.0         3          2         1600      2388       2
# 21596     32  325000.0         2          1         1020      1076       2
#
# ...

# %%
# Redefine X_train and y_train
X_train = df1.drop(['price', 'lat', 'long'], axis = 1)
y_train = df1['price']

# %%
# Create model in OLS
X_int = sm.add_constant(X_train)
model = sm.OLS(y_train, X_int).fit()
summary = model.summary()
summary
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.614
# Model:                            OLS   Adj. R-squared:                  0.613
# Method:                 Least Squares   F-statistic:                     2238.
# Date:                Thu, 20 Apr 2023   Prob (F-statistic):               0.00
# Time:                        20:11:06   Log-Likelihood:            -2.9091e+05
# No. Observations:               21143   AIC:                         5.819e+05
# Df Residuals:                   21127   BIC:                         5.820e+05
# Df Model:                          15
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %% [markdown]
# Observation
#
# R squared valule is 61.4% meaning the model explains 61.4% of the variables.
#
# We note that all p-values are below our threshold of 0.05. Compare to single linear regression, our model's accuracy has improved considerable. This means that results are statistically significant.
#
# Based on above summary model can be summarized as follows;
#
# $y$ = $c$ + $ \beta$ 1 x1$ + $\beta$ 2 x2$ + $\beta$ 3 x3$ +.....+ $\beta$ 19 x19$
#
# Where:
#
# C is the y intercept that is price of the house then there is no variable affecting it.
#
# $\beta$ is the coefficient of the variables
#
# $ \beta$ 1 is coefficient of variable 1
#
# $ \beta$ 2 is coefficient of variable 2 etc...
#
# Lets evaluate the model above using the scikit_learn

# %% [markdown]
# The RMSE is the mean error in $ ie.on aaverage the actual price will be USD 230491 more or less than predicted price. This is not a bad value for the one feature that we used. T he standard deviation of around USD 13136 is also decent,meaning that our model does not appear to be over fitting.

# %%
# Add model to evaluation table
evaluationtable.loc[2] = ['Base Model 2', 'Additional one-hot encoding', model.df_model, round(model.rsquared,3)
                          ,round(model.rsquared_adj,3), int(rmse_scores.mean()), int(rmse_scores.std()) ]

# View our evaluation table
evaluationtable.sort_values(by = 'Adj R-squared', ascending=False)
# Out:
#              baseline_model                  Description   Num Features  \
# 2              Base Model 2  Additional one-hot encoding           15.0
# 0  Simple Linear Regression                  Sqft_living            1.0
#
#    R-squared  Adj R-squared      RMSE  RMSE sd
# 2      0.614          0.613  261890.0  11989.0
# 0      0.493          0.493  261890.0  11989.0

# %% [markdown]
# ### CONCLUSION

# %% [markdown]
# The above implies that testing data worked better than the prediction data hence the increase in a value of the r2 parameters. We can conclude that independent variables affects price of houses as  depicted by r2 values showing the significance between bedrooms,bathrooms, sqft_living, floors, waterfronts, veiw, grade, sqft_above etc. affects the price of housing in the area
#
# A multiple linear regression model was built to predict the house prices based on various features. The model had an R-squared value of 0.614, indicating that the model explains 61.4% of the variability in the data.
#
# Based on the coefficients of the multiple linear regression model, it was found that the square footage of the house had the highest impact on the house price, followed by the grade of the house, and the number of bathrooms.
#
# The model was evaluated using metrics such as root mean squared error and cross-validation score, and was found to have a good fit.
#
# The King County House Sales dataset provides valuable insights into the factors that affect house prices in the region, and can be useful for real estate agents, home buyers, and sellers.

# %% [markdown]
# ### RECOMMENDATIONS

# %% [markdown]
# 1. Homeowners should consider the following when building; bedroom numbers, bathroom numbers, sqft_ living area, sqft lot,quality of the house, sqft basement, vicinity of the house.
# 2. Housing agency should be aware that timing affect the price and should therefore advice homeowners on when to build and sell.
# 3. Consider other algorithms beyond multiple linear regression
# 4. Consider regression methods that can deal with under or over fitting
